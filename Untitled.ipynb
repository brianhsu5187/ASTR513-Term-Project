# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
feat_data = np.load('feat.npz', allow_pickle=True)
ids = feat_data['ids']
features = feat_data['features']
feat_names = feat_data['feat_names']

# %%
feat_data['feat_names']
# Out:
# array(['raenn0', 'raenn1', 'raenn2', 'raenn3', 'raenn4', 'raenn5',
#        'raenn6', 'raenn7', 'raenn8', 'raenn9'], dtype='<U6')

# %%
fig = plt.figure(figsize=(6,6))

plt.scatter(features.T[1],features.T[2])
